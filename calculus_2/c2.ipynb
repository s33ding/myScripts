# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
from sympy.solvers import solve

x, y, z, c, h = symbols('x y z c h')

# %% [markdown]
# EXERCÍCIO 1

# %%
ap3_1 = x**4-4*x*y+y**4+1
ap3_2 = 1+x**2-y**2
ap3_3 = 25+(x-y)**4+(y-1)
ap3_4a = 4*x*y-x**4-2*y**2
ap3_4b = 3*x**4+2*y**2
ap3_5 = 2*x**2 -x*y +y**2 -7*y

ap6 = x**3 +3*x*y**2 -15*x-12*y
teste = 4*x*y - x**4 -2*y**2

f = ap6



#Calculating Derivates
fx = diff(f,x)
fy = diff(f,y)
fyx = diff(fx,y)
fxy = diff(fy,x)
fxx = diff(fx,x)
fyy = diff(fy,y)

def Dfx_calculating(): 
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print('Calculating values inside derivatives')
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print("                    df[x]= ",fx,'\n')
    print('[x] =', x_fx)
    print('[y] =', y_fx)
    print('---------------------------------------------')
    print("                    REPLACING")

    print('[x] = [y]')
    print('[x] =',  x_fx_replaced_with_y_fx)
    print('[y] =', y_fx_resolved_when_x_fx_replaced_with_y_fx)
    print('---------------------------------------------')
    print("                    df[y] = ",fy,'\n')
    print('[x] =', x_fy)
    print('[y] =', y_fy)
    print('---------------------------------------------')
    print("                    REPLACING")
    print('[x] = [y]')
    print('[x] =',  x_fy_replaced_with_y_fy)
    print('[y] =', y_fy_resolved_when_x_fy_replaced_with_y_fy)
    print('---------------------------------------------')

def Dfx_all():
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print('All Derivatives')
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print('f[x,y] = ',f)
    print("df[x]= ",fx)
    print("df[y] = ",fy)
    print('---------------------------------------------')
    print("df[yx] = ",fyx)
    print("df[xy] = ",fxy)
    print("df[xx] = ",fxx)
    print("df[yy] = ",fyy)
    print('---------------------------------------------')

x_fx = solve(fx,x)
y_fx = solve(fx,y)
x_fy = solve(fy,x)
y_fy = solve(fy,y)

x_fx_replaced_with_y_fx = fx.subs(x,y)
y_fx_resolved_when_x_fx_replaced_with_y_fx = solve(x_fx_replaced_with_y_fx,y)
y_fx_replaced_with_x_fx = fx.subs(y,x)
y_fx_resolved_when_x_fx_replaced_with_y_fx = solve(x_fx_replaced_with_y_fx,y)
x_fy_replaced_with_y_fy = fy.subs(x,y)
y_fy_resolved_when_x_fy_replaced_with_y_fy= solve(x_fy_replaced_with_y_fy,y)

def hessiana():
        h_model = Function('f')(x,y)
        return hessian(h_model, (x,y))
        
def calculate_critical_points():
    a,b = critical_points_xy
    determinant = fxx*fyy-fxy*fyx
    h = determinant.subs({x:a,y:b})
    print('determinant = ',determinant)
    print('\nh(x,y) =', h)
    print('fxx =', fxx)
    print('Se h(a,b) > 0 and fxx>0, logo ponto crítico é o ponto mínimo. ')
    print('Se h(a,b) > 0 and fxx<0, logo ponto crítico é o ponto máximo.')
    print('Se h(a,b) < 0, logo ponto crítico é o ponto de sela.')
    print('\nSe h(x,y) == 0,logo nada podemos afirmar.')

def p(number):

    if number == 1:
        return Dfx_calculating()
    if number == 2:
        return Dfx_all()
    if number == 4:
        return hessiana()
    if number == 5:
        return hessiana(calculate_critical_points(critical_points_xy))

# %%
a=1 ; b=1
critical_points()
# Out:
# determinant =  36*x**2 - 36*y**2
#
# h(x,y) = 36*x**2 - 36*y**2
# fxx = 6*x
#
# Se h(x,y) == 0,logo nada podemos afirmar.
# Se h(a,b) > 0 and fxx>0, logo ponto crítico é o ponto mínimo.
# Se h(a,b) > 0 and fxx<0, logo ponto crítico é o ponto máximo.
# Se h(a,b) < 0, logo ponto crítico é o ponto de sela.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Calculating values inside derivatives
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     df[x]=  3*x**2 + 3*y**2 - 15
#
# [x] = [-sqrt(5 - y**2), sqrt(5 - y**2)]
# [y] = [-sqrt(5 - x**2), sqrt(5 - x**2)]
# ---------------------------------------------
#                     REPLACING
# [x] = [y]
# [x] = 6*y**2 - 15
# [y] = [-sqrt(10)/2, sqrt(10)/2]
# ---------------------------------------------
#                     df[y] =  6*x*y - 12
#
# [x] = [2/y]
# [y] = [2/x]
# ---------------------------------------------
#                     REPLACING
# [x] = [y]
# [x] = 6*y**2 - 12
# [y] = [-sqrt(2), sqrt(2)]
# ...
